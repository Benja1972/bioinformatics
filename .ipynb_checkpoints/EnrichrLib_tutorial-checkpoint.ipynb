# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import ErichRLib

# %%
import EnrichRLib as erl

# %% [markdown]
# Gene list may be imported from file or direct entered in code as list object

# %%
gl = [  'CD3E', 'BLK', 'PTPN22', 'PAG1', 'CTLA4', 'PIK3CD', 'LAT2', 'CSK', 
        'CD247', 'CD3G', 'THEMIS', 'PSMB8', 'LCP2', 'GATA3', 'LAT', 'SLA2', 
        'SKAP1', 'TRAT1', 'BCL2', 'CD3D', 'THY1','RUNX1', 'BLK', 'PTPN22']

# %% [markdown]
# # Fetching gene sets from Enrichr website

# %%
# sub directory where gene sets in .gmt format will be placed
lib_dir='_tmp'

# List of gene sets to fetch, by default all gene sets will be fetched
gss = [ 
       'GO_Biological_Process_2018',
       'GO_Cellular_Component_2018',
       'GO_Molecular_Function_2018',
       'KEGG_2016',
       'Reactome_2016'
       ]

erl.get_Enrichr(out_dir='_tmp', libs=gss)
# Out:
# Directory  _tmp  already exists
# GO_Biological_Process_2018  -- DONE
# GO_Cellular_Component_2018  -- DONE
# GO_Molecular_Function_2018  -- DONE
# KEGG_2016  -- DONE
# Reactome_2016  -- DONE

# %% [markdown]
# # Enrichment of single gene set

# %%
# gene set name and file name
lib_dir='_tmp'
gsn = 'Reactome_2016'
gs_fn =lib_dir+'/'+gsn+'.gmt'

# read gmt to python dictionary
gs = erl.read_gmt(gs_fn)

print(gs['Formation of Incision Complex in GG-NER_Homo sapiens_R-HSA-5696395'])
# Out:
# ['UBE2I', 'PARP2', 'USP45', 'PARP1', 'CHD1L', 'RPA2', 'RPA3', 'GTF2H1', 'RAD23B', 'GTF2H2', 'RPA1', 'GTF2H3', 'RAD23A', 'PIAS1', 'GTF2H4', 'GTF2H5', 'PIAS3', 'RBX1', 'DDB2', 'CUL4B', 'ERCC1', 'CUL4A', 'DDB1', 'CDK7', 'ERCC4', 'ERCC5', 'ERCC2', 'ERCC3', 'UBE2V2', 'UBA52', 'MNAT1', 'UBE2N', 'CETN2', 'CCNH', 'XPA', 'XPC', 'UBC', 'SUMO2', 'SUMO1', 'UBB', 'SUMO3', 'RPS27A', 'RNF111']

# %% [markdown]
# ### Enrichment run

# %%
enr = erl.enrich(gl, gs)

# %%
# Plot result as barplot and compare with EnrichR image

import seaborn as sns

ds = enr.head(10)
sns.barplot(y=ds.index,
                x='-log10(p-Val)', 
                color="Red",
                data = ds)
plt.title(gsn)
# Out:
# Text(0.5,1,'Reactome_2016')

# %% [markdown]
# ![title](im/React2016_EnrichTest_bar.png)

# %%
ds
# Out:
#                                                            p-Val  num_list  \
# TCR signaling_Homo sapiens_R-HSA-202403             2.109846e-17        10
# Phosphorylation of CD3 and TCR zeta chains_Homo...  1.116760e-13         6
# Adaptive Immune System_Homo sapiens_R-HSA-1280218   1.167847e-13        13
# Generation of second messenger molecules_Homo s...  1.336622e-12         6
# Immune System_Homo sapiens_R-HSA-168256             2.017948e-12        15
# PD-1 signaling_Homo sapiens_R-HSA-389948            6.403149e-11         5
# Costimulation by the CD28 family_Homo sapiens_R...  1.254283e-10         6
# Downstream TCR signaling_Homo sapiens_R-HSA-202424  8.830089e-10         6
# Innate Immune System_Homo sapiens_R-HSA-168249      4.504628e-09        10
# Translocation of ZAP-70 to Immunological synaps...  6.489045e-09         4
#
#                                                     num_term  \
# TCR signaling_Homo sapiens_R-HSA-202403                  118
# Phosphorylation of CD3 and TCR zeta chains_Homo...        24
# Adaptive Immune System_Homo sapiens_R-HSA-1280218        762
# Generation of second messenger molecules_Homo s...        35
# Immune System_Homo sapiens_R-HSA-168256                 1547
# PD-1 signaling_Homo sapiens_R-HSA-389948                  26
# Costimulation by the CD28 family_Homo sapiens_R...        72
# Downstream TCR signaling_Homo sapiens_R-HSA-202424        99
# Innate Immune System_Homo sapiens_R-HSA-168249           807
# Translocation of ZAP-70 to Immunological synaps...        21
#
#                                                                                                 genes  \
# TCR signaling_Homo sapiens_R-HSA-202403             [CD3E, LAT, CD3D, CSK, TRAT1, CD247, CD3G, PSM...
# Phosphorylation of CD3 and TCR zeta chains_Homo...               [CD3E, CD3D, CSK, CD247, CD3G, PAG1]
# Adaptive Immune System_Homo sapiens_R-HSA-1280218   [CD3E, BLK, LAT, CD3D, CSK, PIK3CD, TRAT1, CTL...
# Generation of second messenger molecules_Homo s...               [CD3E, LAT, CD3D, CD247, CD3G, LCP2]
# Immune System_Homo sapiens_R-HSA-168256             [CD3E, BLK, LAT, CD3D, BCL2, CSK, PIK3CD, LAT2...
# PD-1 signaling_Homo sapiens_R-HSA-389948                               [CD3E, CD3D, CSK, CD247, CD3G]
# Costimulation by the CD28 family_Homo sapiens_R...              [CD3E, CD3D, CSK, CTLA4, CD247, CD3G]
# Downstream TCR signaling_Homo sapiens_R-HSA-202424            [CD3E, CD3D, TRAT1, CD247, CD3G, PSMB8]
# Innate Immune System_Homo sapiens_R-HSA-168249      [LAT, BCL2, CSK, PIK3CD, LAT2, TRAT1, CD247, C...
# Translocation of ZAP-70 to Immunological synaps...                          [CD3E, CD3D, CD247, CD3G]
#
#                                                                                            term_genes  \
# TCR signaling_Homo sapiens_R-HSA-202403             [FBXW11, PSMB9, PSMC6, CD4, PSMC4, PSMC5, PSMC...
# Phosphorylation of CD3 and TCR zeta chains_Homo...  [HLA-DRB5, CD3G, TRBV12-3, PTPRJ, CD3E, CD3D, ...
# Adaptive Immune System_Homo sapiens_R-HSA-1280218   [EGF, WSB1, BAD, AP1S1, FRS2, LNPEP, PSMB9, DY...
# Generation of second messenger molecules_Homo s...  [HLA-DRB5, VASP, ENAH, ZAP70, LCK, CD4, HLA-DR...
# Immune System_Homo sapiens_R-HSA-168256             [BAD, FRS3, FRS2, LNPEP, IL31RA, ORAI1, RNF220...
# PD-1 signaling_Homo sapiens_R-HSA-389948            [HLA-DRB5, PTPN11, PDCD1LG2, LCK, CD4, HLA-DRA...
# Costimulation by the CD28 family_Homo sapiens_R...  [LYN, PPP2R5C, PTPN11, PPP2R5B, PPP2R5E, PPP2R...
# Downstream TCR signaling_Homo sapiens_R-HSA-202424  [FBXW11, PSMB9, PSMC6, CD4, PSMC4, PSMC5, PSMC...
# Innate Immune System_Homo sapiens_R-HSA-168249      [BAD, FRS3, FRS2, GRIN2D, GRIN2C, PSMB9, PSMC6...
# Translocation of ZAP-70 to Immunological synaps...  [HLA-DRB5, CD3G, TRBV12-3, CD3E, CD3D, ZAP70, ...
#
#                                                            p-adj  \
# TCR signaling_Homo sapiens_R-HSA-202403             4.620562e-15
# Phosphorylation of CD3 and TCR zeta chains_Homo...  8.525286e-12
# Adaptive Immune System_Homo sapiens_R-HSA-1280218   8.525286e-12
# Generation of second messenger molecules_Homo s...  7.318008e-11
# Immune System_Homo sapiens_R-HSA-168256             8.838614e-11
# PD-1 signaling_Homo sapiens_R-HSA-389948            2.337150e-09
# Costimulation by the CD28 family_Homo sapiens_R...  3.924114e-09
# Downstream TCR signaling_Homo sapiens_R-HSA-202424  2.417237e-08
# Innate Immune System_Homo sapiens_R-HSA-168249      1.096126e-07
# Translocation of ZAP-70 to Immunological synaps...  1.421101e-07
#
#                                                     -log10(p-adj)  \
# TCR signaling_Homo sapiens_R-HSA-202403                 14.335305
# Phosphorylation of CD3 and TCR zeta chains_Homo...      11.069291
# Adaptive Immune System_Homo sapiens_R-HSA-1280218       11.069291
# Generation of second messenger molecules_Homo s...      10.135607
# Immune System_Homo sapiens_R-HSA-168256                 10.053616
# PD-1 signaling_Homo sapiens_R-HSA-389948                 8.631314
# Costimulation by the CD28 family_Homo sapiens_R...       8.406258
# Downstream TCR signaling_Homo sapiens_R-HSA-202424       7.616681
# Innate Immune System_Homo sapiens_R-HSA-168249           6.960139
# Translocation of ZAP-70 to Immunological synaps...       6.847375
#
#                                                     -log10(p-Val)
# TCR signaling_Homo sapiens_R-HSA-202403                 16.675749
# Phosphorylation of CD3 and TCR zeta chains_Homo...      12.952040
# Adaptive Immune System_Homo sapiens_R-HSA-1280218       12.932614
# Generation of second messenger molecules_Homo s...      11.873991
# Immune System_Homo sapiens_R-HSA-168256                 11.695090
# PD-1 signaling_Homo sapiens_R-HSA-389948                10.193606
# Costimulation by the CD28 family_Homo sapiens_R...       9.901604
# Downstream TCR signaling_Homo sapiens_R-HSA-202424       9.054035
# Innate Immune System_Homo sapiens_R-HSA-168249           8.346341
# Translocation of ZAP-70 to Immunological synaps...       8.187819

# %% [markdown]
# ![title](im/React2016_EnrichTest_table.png)

# %% [markdown]
# # Enrichment of several gene sets: batch analysis

# %%
# List of gene sets as above
gss = [ 
       'GO_Biological_Process_2018',
       'GO_Cellular_Component_2018',
       'GO_Molecular_Function_2018',
       'KEGG_2016',
       'Reactome_2016'
       ]

# %% [markdown]
# ### Batch enrichment

# %%
enrr = erl.enrich_gs(gl,gss, path_lib=lib_dir)
# Out:
# GO_Biological_Process_2018 492
# GO_Cellular_Component_2018 21
# GO_Molecular_Function_2018 59
# KEGG_2016 90
# Reactome_2016 219

# %% [markdown]
# ### Plots

# %%
enrr.sort_values('p-Val', axis=0, inplace = True)
ds = enrr.head(20)

f, ax = plt.subplots()
sns.barplot(y=ds.index,
            x='-log10(p-Val)',
            ax = ax, 
            color="Red", 
            data = ds)
ax.set_title('All terms')
# Out:
# Text(0.5,1,'All terms')

# %% [markdown]
# # Clustering

# %%
# For futher analysis it is convinient to filter terms by p-value for
enrr = enrr[enrr['p-Val']<0.001]
len(enrr)
# Out:
# 105

# %% [markdown]
# ## Calculate closeness by kappa-score

# %%
dd = erl.kappa_matrx(gl,enrr)

# %%
## Show cluster based on kappa-score closeness

grid = sns.clustermap(dd, cmap='Blues', figsize=(16, 16))

# %% [markdown]
# ## Clastering:  top level

# %%
## Cluster: this calculate and add cluster number column
enrr = erl.cluster(gl,enrr)

# Make additional calculation on existing columns for visualization
enrr.loc[:,'ass_genes_percnt'] = 100*enrr.loc[:,'num_list']/enrr.loc[:,'num_term']
enrr.sort_values('cluster', axis=0, inplace = True)

# use consistent discrete palette
cm = 'tab20'

ds = enrr.head(40)

f, ax = plt.subplots(figsize=(18.5, 8.5))
sns.barplot(y=ds.index,
            x='-log10(p-Val)',
            ax = ax, 
            hue ='cluster',
            dodge=False,
            data = ds,
            palette = cm)
ax.set_title('All terms')
# Out:
# Text(0.5,1,'All terms')

# %%
f, ax = plt.subplots(figsize=(18.5, 8.5))
sns.barplot(y=ds.index,
            x='ass_genes_percnt',
            ax = ax, 
            hue ='cluster', 
            dodge=False,
            data = ds,
            palette = cm)
ax.set_title('All terms')
ax.set_xlabel('%Genes/Term')
# Out:
# Text(0.5,0,'%Genes/Term')

# %% [markdown]
# # Network construction based on cluster

# %%
## Graph and network
## control conectivity by kappa score parameter, default kappa=0.4
G,enrrr, nt = erl.make_graph(gl, enrr, kappa=0.4)

# %%
erl.draw_graph(G, spring=0.7, pval_prcnt=0.5, palette=cm)

# %%
enrrr.sort_values('cluster', axis=0, inplace = True)

# use consistent discrete palette
cm = 'tab20'

dss = enrrr.head(40)

f, ax = plt.subplots(figsize=(18.5, 8.5))
sns.barplot(y=dss.index,
            x='-log10(p-Val)',
            ax = ax, 
            hue ='cluster',
            dodge=False,
            data = dss,
            palette = cm)
ax.set_title('All terms')




#G.nodes['T cell receptor signaling pathway (GO:0050852)']
# Out:
# Text(0.5,1,'All terms')

# %%
#G.nodes['antigen receptor-mediated signaling pathway (GO:0050851)']

# %%
setR = set(gl)
set1 = set(list(enrr['term_genes'].loc['T cell receptor signaling pathway (GO:0050852)']))
set2 = set(list(enrr['term_genes'].loc['antigen receptor-mediated signaling pathway (GO:0050851)']))

kp = erl.coeff_kappa(setR,set1,set2)

# %%
kp
# Out:
# 0.22535211

# %%
#enrr.head(40).index
#enrr.loc['T cell receptor signaling pathway (GO:0050852)']

# %% [markdown]
# ## Exporting network tables for Cytoscape

# %%
# If save result and network for Cytoscape
exp_name='GO_KEGG_React'

SAVE = False

if SAVE:
    enrr.to_csv(exp_name+'-enrich.txt', sep="\t")
    nt.to_csv(exp_name+'-network.txt', sep="\t")
    enrrr.to_csv(exp_name+'-network_table.txt', sep="\t")

# %% [markdown]
# ![title](im/React2016_EnrichTest_net.png)

# %% [markdown]
# # ClueGO for same gene list and coresponding gene sets

# %% [markdown]
# ![title](im/React2016_EnrichTest_netClue.png)

# %%
# import networkx as nx
cl = [G.nodes[v]['cluster'] for v in G] 
# sz = [G.nodes[v]['mlog10pVal']*100 for v in G] 
# shr=10
# # lb_M = {v:v for v in G if G.nodes[v]['num_list']/G.nodes[v]['num_term']>shr}
# # lb_m = {v:v for v in G if G.nodes[v]['num_list']/G.nodes[v]['num_term']<=shr}
# lb_M = {v:v for v in G if G.nodes[v]['mlog10pVal']>shr}
# lb_m = {v:v for v in G if G.nodes[v]['mlog10pVal']<=shr}



# pos=nx.spring_layout(G,k=.2, iterations=100)
# f1, ax1 = plt.subplots(figsize=(20, 20))
#    #pos=nx.kamada_kawai_layout(G)  
# nx.draw(G, pos=pos,
#         #with_labels = True,
#         labels = lb_M,
#         node_color = cl,
#         node_size =  sz,
#         font_size=14,
#         font_weight='bold',
#         cmap = cm) 


# nx.draw(G, pos=pos,
#         #with_labels = True,
#         labels = lb_m,
#         node_color = cl,
#         node_size =  sz,
#         font_size=6,
#         cmap = cm)

# %%
cl
# Out:
# [2,
#  24,
#  25,
#  23,
#  31,
#  6,
#  1,
#  10,
#  1,
#  30,
#  11,
#  13,
#  1,
#  4,
#  2,
#  15,
#  1,
#  2,
#  9,
#  5,
#  1,
#  13,
#  13,
#  27,
#  29,
#  13,
#  13,
#  8,
#  6,
#  1,
#  15,
#  15,
#  31,
#  1,
#  23,
#  6,
#  19,
#  1,
#  8,
#  26,
#  27,
#  15,
#  28,
#  12,
#  1,
#  1,
#  1,
#  1,
#  2,
#  3,
#  31,
#  13,
#  13,
#  19,
#  13,
#  2,
#  13,
#  16,
#  15,
#  2,
#  13,
#  1,
#  26,
#  28,
#  5,
#  13,
#  1,
#  1,
#  15,
#  1,
#  1,
#  18,
#  18,
#  9,
#  12,
#  1,
#  30,
#  18,
#  13,
#  13,
#  1,
#  23,
#  7,
#  13,
#  9,
#  23,
#  1,
#  22,
#  1,
#  17,
#  14,
#  1,
#  9,
#  3,
#  1,
#  30,
#  13,
#  20,
#  15,
#  13,
#  26,
#  13,
#  21,
#  23]
