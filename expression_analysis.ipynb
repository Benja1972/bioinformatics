# %%
import numpy as np
import yaml
import os
from os.path import join 
import pybedtools as pb
import gffutils
from pybedtools.featurefuncs import TSS
from gffutils.helpers import asinterval
import matplotlib.pyplot as plt
import metaseq
import pandas as pd
from metaseq.results_table import ResultsTable, DESeq2Results

# %%
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 12

# %%
tbl_f = 'TLX3vsRAG_DESeq2-results.txt'

tbl = ResultsTable(tbl_f, import_kwargs=dict(index_col=0))
tbl.data['TLX3-mean'] = (tbl.data['TLX3.1_1']+tbl.data['TLX3.1_5']+tbl.data['TLX3.1_P'])/3.
tbl.data['RAG-mean'] = (tbl.data['R2.RAG1W.RAG1']+tbl.data['RAGS.RAGZ']+tbl.data['RAGZ'])/3.

# %%
list ={
    'Samsn1-003':'ENSMUST00000114239',
    'Samsn1-001':'ENSMUST00000114240',
    'Samsn1-004':'ENSMUST00000139691',
    'Samsn1-007':'ENSMUST00000150248',
    'Samsn1-006':'ENSMUST00000147447',
    '1700041M19Rik-003':'ENSMUST00000208105',
    '1700041M19Rik-001':'ENSMUST00000190908',
    '1700041M19Rik-004':'ENSMUST00000207519',
    '1700041M19Rik-002':'ENSMUST00000190317',
    '1700041M19Rik-005':'ENSMUST00000207924',
    'Nrip1-001':'ENSMUST00000121927',
    'Nrip1-003':'ENSMUST00000054178',
    'Nrip1-006':'ENSMUST00000140483',
    'Nrip1-005':'ENSMUST00000141182',
    'Nrip1-004':'ENSMUST00000128871',
    'Nrip1-002':'ENSMUST00000145649',
    'D16Ertd472e-001':'ENSMUST00000114220',
    'D16Ertd472e-002':'ENSMUST00000114219',
    'D16Ertd472e-003':'ENSMUST00000114218',
    'Cxadr-001':'ENSMUST00000023572',
    'Cxadr-002':'ENSMUST00000114229',
    'mir99a':'ENSMUST00000083596',
    'mir125b':'ENSMUST00000083538',
    'Usp25':'ENSMUST00000023580',
    'Mir99ahg-001':'ENSMUST00000193546',
    'Mir99ahg-002':'ENSMUST00000179255',
    'Btg3-001':'ENSMUST00000023570',
    'Btg3-002':'ENSMUST00000148124'
    }


d = {'Gene name':list.keys(), 
     'Gene':list.values()}

# %%
expr_df = pd.DataFrame(data=d, index=d['Gene'])
expr_df.index.name = 'Gene'

#expr_df

# %%
sel_df = tbl.data.ix[expr_df['Gene']][['log2FoldChange', 'TLX3-mean', 'RAG-mean']]

# %%
tot_df = pd.concat([sel_df,expr_df.drop(['Gene'], axis=1)], axis=1)
tot_df.sort_values(by='Gene name')
# Out:
#                     log2FoldChange     TLX3-mean     RAG-mean  \
# Gene
# ENSMUST00000190908             NaN           NaN          NaN
# ENSMUST00000190317             NaN           NaN          NaN
# ENSMUST00000208105             NaN           NaN          NaN
# ENSMUST00000207519             NaN           NaN          NaN
# ENSMUST00000207924             NaN           NaN          NaN
# ENSMUST00000023570        0.861073    832.827310   456.647110
# ENSMUST00000148124       -0.535314      0.000000     0.532388
# ENSMUST00000023572       -1.410527    125.244712   339.128789
# ENSMUST00000114229       -0.146632     80.996285    90.022236
# ENSMUST00000114220        1.172483   1148.783124   508.907690
# ENSMUST00000114219             NaN      0.000000     0.000000
# ENSMUST00000114218             NaN      0.000000     0.000000
# ENSMUST00000193546             NaN           NaN          NaN
# ENSMUST00000179255             NaN           NaN          NaN
# ENSMUST00000121927        1.992434  11309.098059  2820.171417
# ENSMUST00000145649       -1.131167    191.500138   421.945404
# ENSMUST00000054178        1.624187      1.577279     0.226175
# ENSMUST00000128871             NaN      0.000000     0.000000
# ENSMUST00000141182       -1.022354     81.238040   166.153457
# ENSMUST00000140483       -1.284794     17.765096    43.804030
# ENSMUST00000114240        3.385052      6.001561     0.306213
# ENSMUST00000114239        2.507570      5.274499     0.599943
# ENSMUST00000139691        2.551926    386.855985    65.828699
# ENSMUST00000147447             NaN      0.000000     0.000000
# ENSMUST00000150248        1.358789    129.182569    50.381405
# ENSMUST00000023580        0.686839  11909.497207  7394.138757
# ENSMUST00000083538       -0.494863      0.000000     0.452349
# ENSMUST00000083596       -3.821833      0.000000     5.732533
#
#                             Gene name
# Gene
# ENSMUST00000190908  1700041M19Rik-001
# ENSMUST00000190317  1700041M19Rik-002
# ENSMUST00000208105  1700041M19Rik-003
# ENSMUST00000207519  1700041M19Rik-004
# ENSMUST00000207924  1700041M19Rik-005
# ENSMUST00000023570           Btg3-001
# ENSMUST00000148124           Btg3-002
# ENSMUST00000023572          Cxadr-001
# ENSMUST00000114229          Cxadr-002
# ENSMUST00000114220    D16Ertd472e-001
# ENSMUST00000114219    D16Ertd472e-002
# ENSMUST00000114218    D16Ertd472e-003
# ENSMUST00000193546       Mir99ahg-001
# ENSMUST00000179255       Mir99ahg-002
# ENSMUST00000121927          Nrip1-001
# ENSMUST00000145649          Nrip1-002
# ENSMUST00000054178          Nrip1-003
# ENSMUST00000128871          Nrip1-004
# ENSMUST00000141182          Nrip1-005
# ENSMUST00000140483          Nrip1-006
# ENSMUST00000114240         Samsn1-001
# ENSMUST00000114239         Samsn1-003
# ENSMUST00000139691         Samsn1-004
# ENSMUST00000147447         Samsn1-006
# ENSMUST00000150248         Samsn1-007
# ENSMUST00000023580              Usp25
# ENSMUST00000083538            mir125b
# ENSMUST00000083596             mir99a
